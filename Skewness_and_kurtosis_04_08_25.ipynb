# %% [markdown]
# <a href="https://colab.research.google.com/github/VikrantPhogat08/Regrestion-Analysis/blob/main/Skewness_and_kurtosis_04_08_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')\
import yfinance as yf
import datetime
from datetime import date, timedelta

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import datetime
from datetime import date, timedelta

# %%
df=yf.download('TCS.NS',
               start='2019-01-01',
               end="2025-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
# Price             Close         High          Low         Open   Volume
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2019-01-01  1717.571167  1724.070236  1701.503872  1711.433072  1094883
# 2019-01-02  1736.075806  1746.140317  1715.043907  1719.557181  2100463
# 2019-01-03  1714.998779  1755.618241  1708.815617  1732.194396  2611668
# 2019-01-04  1694.147339  1716.126957  1661.787192  1715.043816  4280862
# 2019-01-07  1713.148315  1722.987273  1697.893430  1707.642144  1856423
# ...                 ...          ...          ...          ...      ...
# 2024-12-24  4118.851562  4156.792892  4097.959002  4097.959002  1181886
# 2024-12-26  4108.602539  4139.004973  4083.028905  4118.851529  1208464
# 2024-12-27  4104.414062  4120.280532  4087.069359  4102.590812   858100
# 2024-12-30  4098.452148  4138.364460  4052.331448  4090.765525  1527169
# 2024-12-31  4035.380859  4079.875837  3973.541418  4074.997474  1555429
#
# [1481 rows x 5 columns]

# %%
df.isnull()
# Out:
# Price       Close   High    Low   Open Volume
# Ticker     TCS.NS TCS.NS TCS.NS TCS.NS TCS.NS
# Date
# 2019-01-01  False  False  False  False  False
# 2019-01-02  False  False  False  False  False
# 2019-01-03  False  False  False  False  False
# 2019-01-04  False  False  False  False  False
# 2019-01-07  False  False  False  False  False
# ...           ...    ...    ...    ...    ...
# 2024-12-24  False  False  False  False  False
# 2024-12-26  False  False  False  False  False
# 2024-12-27  False  False  False  False  False
# 2024-12-30  False  False  False  False  False
# 2024-12-31  False  False  False  False  False
#
# [1481 rows x 5 columns]

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker       TCS.NS       TCS.NS       TCS.NS       TCS.NS        TCS.NS
# count   1481.000000  1481.000000  1481.000000  1481.000000  1.481000e+03
# mean    2945.636060  2974.803200  2917.329823  2946.614053  2.745963e+06
# std      758.172475   762.247864   754.219393   757.721769  1.660880e+06
# min     1513.736938  1559.157813  1383.094924  1442.830363  1.548950e+05
# 25%     2063.993408  2083.714306  2044.661671  2065.475868  1.711510e+06
# 50%     3094.846191  3123.524656  3070.495345  3097.296142  2.316539e+06
# 75%     3457.184570  3483.982551  3426.322568  3455.391937  3.224657e+06
# max     4476.749512  4514.598506  4435.705272  4498.623077  1.983933e+07

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   TCS.NS    0
# High    TCS.NS    0
# Low     TCS.NS    0
# Open    TCS.NS    0
# Volume  TCS.NS    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1481 entries, 2019-01-01 to 2024-12-31
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (Close, TCS.NS)   1481 non-null   float64
#  1   (High, TCS.NS)    1481 non-null   float64
#  2   (Low, TCS.NS)     1481 non-null   float64
#  3   (Open, TCS.NS)    1481 non-null   float64
#  4   (Volume, TCS.NS)  1481 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 69.4 KB

# %%
df['Close'].plot(figsize=(16,6)).axhline(y=4060,color='r',linestyle='--',label='reference line')
plt.legend()
plt.show()

# %%
df["Close_simple_return"]=df["Close"].pct_change()

# %%
df["Close_simple_return"]
# Out:
# Date
# 2019-01-01         NaN
# 2019-01-02    0.010774
# 2019-01-03   -0.012141
# 2019-01-04   -0.012158
# 2019-01-07    0.011216
#                 ...
# 2024-12-24    0.005098
# 2024-12-26   -0.002488
# 2024-12-27   -0.001019
# 2024-12-30   -0.001453
# 2024-12-31   -0.015389
# Name: Close_simple_return, Length: 1481, dtype: float64

# %%
df
# Out:
# Price             Close         High          Low         Open   Volume  \
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2019-01-01  1717.571167  1724.070236  1701.503872  1711.433072  1094883
# 2019-01-02  1736.075806  1746.140317  1715.043907  1719.557181  2100463
# 2019-01-03  1714.998779  1755.618241  1708.815617  1732.194396  2611668
# 2019-01-04  1694.147339  1716.126957  1661.787192  1715.043816  4280862
# 2019-01-07  1713.148315  1722.987273  1697.893430  1707.642144  1856423
# ...                 ...          ...          ...          ...      ...
# 2024-12-24  4118.851562  4156.792892  4097.959002  4097.959002  1181886
# 2024-12-26  4108.602539  4139.004973  4083.028905  4118.851529  1208464
# 2024-12-27  4104.414062  4120.280532  4087.069359  4102.590812   858100
# 2024-12-30  4098.452148  4138.364460  4052.331448  4090.765525  1527169
# 2024-12-31  4035.380859  4079.875837  3973.541418  4074.997474  1555429
#
# ...

# %%
df["Close_simple_return"].plot(figsize=(10,7))
# Out:
# <Axes: xlabel='Date'>

# %%
df["Close_simple_return"].plot(figsize=(10,7)).axhline(y=0,color='r',linestyle='--',label='reference line')
plt.legend()

# %%
df["Close_simple_return"].describe()
# Out:
# count    1480.000000
# mean        0.000693
# std         0.015246
# min        -0.094104
# 25%        -0.006967
# 50%         0.000431
# 75%         0.008467
# max         0.098451
# Name: Close_simple_return, dtype: float64

# %%
df["Close_simple_return"].corr(df["Close_simple_return"].shift(1))
# Out:
# np.float64(-0.028119224848929335)

# %%
#calcutate skewness and kurtosis
skewness=df["Close_simple_return"].skew()
kurtosis=df["Close_simple_return"].kurtosis()
print("Skewness:",skewness)
print("Kurtosis:",kurtosis)
# Out:
# Skewness: 0.033058515654819015
# Kurtosis: 4.574632312634525

# %%
skewness1=df["Close"].skew()
kurtosis1=df["Close"].kurtosis()
print("Skewness:",skewness1)
print("Kurtosis:",kurtosis1)
# Out:
# Skewness: Ticker
# TCS.NS   -0.155712
# dtype: float64
# Kurtosis: Ticker
# TCS.NS   -1.022916
# dtype: float64

# %%
import seaborn as sns

# %%
v=sns.regplot(x="Close",y="Volume",data=df,
              line_kws={'color':'red'})

# %%
v.set(title=f"TCS.NS vs. Vol ($\\rho$={0:.2f})",
      ylabel='Vol log returns',
      xlabel='TCS.NS log returns')
# Out:
# [Text(0.5, 1.0, 'TCS.NS vs. Vol ($\\rho$=0.00)'),
#  Text(24.000000000000007, 0.5, 'Vol log returns'),
#  Text(0.5, 24.0, 'TCS.NS log returns')]

# %%
v
# Out:
# <Axes: title={'center': 'TCS.NS vs. Vol ($\\rho$=0.00)'}, xlabel='TCS.NS log returns', ylabel='Vol log returns'>

# %%
corr=df[["Close","Volume"]].corr("pearson")

# %%
corr
# Out:
# Price             Close    Volume
# Ticker           TCS.NS    TCS.NS
# Price  Ticker
# Close  TCS.NS  1.000000 -0.285727
# Volume TCS.NS -0.285727  1.000000

# %%
v=sns.regplot(x="Close",y="Volume",data=df,
              line_kws={'color':'red'})
v.set(title=f"TCS.NS vs. Vol ($\\rho$={0:.2f})",
      ylabel='Vol',
      xlabel='TCS.NS')
# Out:
# [Text(0.5, 1.0, 'TCS.NS vs. Vol ($\\rho$=0.00)'),
#  Text(0, 0.5, 'Vol'),
#  Text(0.5, 0, 'TCS.NS')]
